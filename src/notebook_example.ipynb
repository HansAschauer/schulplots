# %% [markdown]
# # Run schulplots in Jupyter Notebook
# ## Install schulplots and clone examples from github

# %%
# !pip install schulplots
# !pip install github-clone
# !ghclone https://github.com/HansAschauer/schulplots/tree/main/examples
# Out:
# Collecting schulplots
#   Downloading schulplots-0.8.5-py3-none-any.whl (19 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from schulplots) (6.0.1)
# Collecting cattrs<24.0.0,>=23.1.2 (from schulplots)
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from schulplots) (3.7.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.1 in /usr/local/lib/python3.10/dist-packages (from schulplots) (1.23.5)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from schulplots) (3.1.1)
# Requirement already satisfied: attrs>=20 in /usr/local/lib/python3.10/dist-packages (from cattrs<24.0.0,>=23.1.2->schulplots) (23.1.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs<24.0.0,>=23.1.2->schulplots) (1.1.3)
# Requirement already satisfied: typing_extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs<24.0.0,>=23.1.2->schulplots) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.1->schulplots) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->schulplots) (1.16.0)
# Installing collected packages: cattrs, schulplots
# Successfully installed cattrs-23.1.2 schulplots-0.8.5
# Collecting github-clone
#   Downloading github_clone-1.2.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from github-clone) (2.31.0)
# Collecting docopt>=0.6.2 (from github-clone)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->github-clone) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->github-clone) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->github-clone) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->github-clone) (2023.7.22)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=f89bf02e9c0d2e0576b52e7d66b795df9aca881ced7a2b1f08400c9be3149bc6
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, github-clone
# Successfully installed docopt-0.6.2 github-clone-1.2.0
# Cloning into 'examples'...
# done.

# %% [markdown]
# ## Do some magic required to get the coordinate systems right in Jupyter Notebooks

# %%
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}

# %% [markdown]
# ##  Generate the plot. It is also saved as `tmp_schulplots/plt.png`

# %%
from schulplots.main import generate_plot
generate_plot("examples/example_lines.yaml", "example_lines.png")

# %%
generate_plot("examples/plot_config.yaml")

# %% [markdown]
# ## You can also run the `schulplots` binary
# This will create a PNG file in the current folder -- just click on the folder symbol in the left panel.

# %%
! schulplots examples/plot_config1.yaml
